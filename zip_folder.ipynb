# %%
# %pip install -qr requirements.txt

# %%
import os
import zipfile

from os.path import join
from os import walk

# %%
# %cd data/New_Data/OS1-64_2022-11-21/modified
# Out:
# D:\yolov5-on-lidar\data\New_Data

# %%
zip_out_path = join("..","out.zip")
zip_in_path = join(".")

# %%
with zipfile.ZipFile(zip_out_path, 'w', zipfile.ZIP_DEFLATED) as zf:
    for dirname, subdirs, files in walk(zip_in_path):
        zf.write(dirname)
        print(f"Zipping {dirname}")
        for i,filename in enumerate(filter(lambda x: x.endswith(".png"),files)):
            zf.write(join(dirname, filename))
            if i % 100 == 0:
                print(f"Finished {i} files in that folder")
print(f"Completed zipping!")
# Out:
# Zipping .
# Zipping .\OS1-64_2022-11-21
# Zipping .\OS1-64_2022-11-21\Section1
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\4
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\4\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\1
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\1\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\3
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\3\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\2
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\2\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\5
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\5\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\6
# Zipping .\OS1-64_2022-11-21\Section1\2022-11-21-08-14-55_OS-1-64-122225003356-1024x20\split_files\6\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Zipping .\OS1-64_2022-11-21\Section2
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\2
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\2\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\1
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\1\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\3
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\3\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\4
# Zipping .\OS1-64_2022-11-21\Section2\2022-11-21-08-44-40_OS-1-64-122225003356-1024x20\split_files\4\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\3
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\3\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\2
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\2\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\1
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\1\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\4
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\4\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\5
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\5\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\6
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\6\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
# Finished 2600 files in that folder
# Finished 2700 files in that folder
# Finished 2800 files in that folder
# Finished 2900 files in that folder
# Finished 3000 files in that folder
# Finished 3100 files in that folder
# Finished 3200 files in that folder
# Finished 3300 files in that folder
# Finished 3400 files in that folder
# Finished 3500 files in that folder
# Finished 3600 files in that folder
# Finished 3700 files in that folder
# Finished 3800 files in that folder
# Finished 3900 files in that folder
# Finished 4000 files in that folder
# Finished 4100 files in that folder
# Finished 4200 files in that folder
# Finished 4300 files in that folder
# Finished 4400 files in that folder
# Finished 4500 files in that folder
# Finished 4600 files in that folder
# Finished 4700 files in that folder
# Finished 4800 files in that folder
# Finished 4900 files in that folder
# Finished 5000 files in that folder
# Finished 5100 files in that folder
# Finished 5200 files in that folder
# Finished 5300 files in that folder
# Finished 5400 files in that folder
# Finished 5500 files in that folder
# Finished 5600 files in that folder
# Finished 5700 files in that folder
# Finished 5800 files in that folder
# Finished 5900 files in that folder
# Finished 6000 files in that folder
# Finished 6100 files in that folder
# Finished 6200 files in that folder
# Finished 6300 files in that folder
# Finished 6400 files in that folder
# Finished 6500 files in that folder
# Finished 6600 files in that folder
# Finished 6700 files in that folder
# Finished 6800 files in that folder
# Finished 6900 files in that folder
# Finished 7000 files in that folder
# Finished 7100 files in that folder
# Finished 7200 files in that folder
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\7
# Zipping .\OS1-64_2022-11-21\Section3\2022-11-21-17-25-12_OS-1-64-122225003356-1024x20\split_files\7\signal
# Finished 0 files in that folder
# Finished 100 files in that folder
# Finished 200 files in that folder
# Finished 300 files in that folder
# Finished 400 files in that folder
# Finished 500 files in that folder
# Finished 600 files in that folder
# Finished 700 files in that folder
# Finished 800 files in that folder
# Finished 900 files in that folder
# Finished 1000 files in that folder
# Finished 1100 files in that folder
# Finished 1200 files in that folder
# Finished 1300 files in that folder
# Finished 1400 files in that folder
# Finished 1500 files in that folder
# Finished 1600 files in that folder
# Finished 1700 files in that folder
# Finished 1800 files in that folder
# Finished 1900 files in that folder
# Finished 2000 files in that folder
# Finished 2100 files in that folder
# Finished 2200 files in that folder
# Finished 2300 files in that folder
# Finished 2400 files in that folder
# Finished 2500 files in that folder
